# %%
from learned_noise_motion import LearnedNoiseMotionLoss
import torch

l = LearnedNoiseMotionLoss()
p = torch.randn(4, 20, 5)
t = torch.randn(4, 20, 5)
lq = torch.randn(4, 20, 4)
lr = torch.randn(4, 20, 4)
s = torch.randn(4, 20, 5)
gs = torch.randn(4, 20, 5)
l.forward(p, t, lq, lr, s, gs)
# Out:
# tensor(10.1690)
